# %%
# Install required packages (auto-skipped if already installed)
import importlib
if importlib.util.find_spec('qiskit') is None:
    # !pip install -q qiskit qiskit-aer qiskit-ibm-runtime pylatexenc
else:
    print("\u2713 Packages already installed")

# To run on real quantum hardware, uncomment and fill in your credentials:
# from qiskit_ibm_runtime import QiskitRuntimeService
# QiskitRuntimeService.save_account(
#     token="<your-api-key>",
#     instance="<your-crn>",
#     overwrite=True
# )

# %% [markdown]
# # Portar código para o Qiskit Serverless
#
# import Tabs from '@theme/Tabs';
# import TabItem from '@theme/TabItem';
#
#
#
# O exemplo a seguir demonstra como portar código existente para aproveitar o Qiskit Serverless.
# > **Note:** O código a seguir assume que você já salvou suas credenciais. Caso ainda não tenha feito isso, siga as instruções em [Configure sua conta IBM Cloud](/guides/cloud-setup-untrusted) para autenticar com sua chave de API.
#
# ## Atualize o experimento
# <Tabs>
#   <TabItem value="LocalExperiment" label="Experimento Local">
